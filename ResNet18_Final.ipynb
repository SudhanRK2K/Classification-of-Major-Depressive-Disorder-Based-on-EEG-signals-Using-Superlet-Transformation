# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau, CosineAnnealingLR
from torchvision import transforms, datasets, models
from torch.utils.data import random_split, DataLoader
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, precision_score, recall_score, f1_score
import numpy as np

# %% [markdown]
# Data Augmentation

# %%
def get_augmentations():
    return transforms.Compose([
        transforms.RandomResizedCrop(224, scale=(0.8, 1.0)),
        transforms.RandomHorizontalFlip(p=0.5),
        transforms.RandomVerticalFlip(p=0.5),
        transforms.RandomRotation(30),
        transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.3, hue=0.1),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

# %% [markdown]
# Pre-Trainned model with Fine Tuning

# %%
class TransferLearningModel(nn.Module):
    def __init__(self):
        super(TransferLearningModel, self).__init__()
        self.model = models.resnet18(pretrained=True)
        # Freeze initial layers
        for param in self.model.parameters():
            param.requires_grad = False
        # Fine-tune the last two layers
        for param in self.model.layer4.parameters():
            param.requires_grad = True
        # Replace the final fully connected layer
        self.model.fc = nn.Sequential(
            nn.Linear(self.model.fc.in_features, 128),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(128, 1)
        )

    def forward(self, x):
        return torch.sigmoid(self.model(x))

# %% [markdown]
# Load and Split data

# %%
def load_and_split_data(healthy_folder, mdd_folder, batch_size=16):
    transform = get_augmentations()
    dataset = datasets.ImageFolder(root=os.path.dirname(healthy_folder), transform=transform)

    # Use 80% for training and 20% for validation
    train_size = int(0.8 * len(dataset))
    val_size = len(dataset) - train_size
    train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=4, pin_memory=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, num_workers=4, pin_memory=True)

    return train_loader, val_loader

# %% [markdown]
# Train and Evaluate

# %%
def train_and_evaluate(model, train_loader, val_loader, num_epochs=100):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    model = model.to(device)

    # Weighted loss for class imbalance (if any)
    pos_weight = torch.tensor([2.0]).to(device)  # Adjust based on dataset
    criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight)

    # Advanced optimizer
    optimizer = optim.AdamW(model.parameters(), lr=0.0001, weight_decay=1e-4)
    scheduler = CosineAnnealingLR(optimizer, T_max=num_epochs, eta_min=1e-6)

    best_acc = 0.0

    # Lists to store loss and accuracy values for plotting
    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []

    for epoch in range(num_epochs):
        # Training loop
        model.train()
        total_train_loss = 0
        correct_train = 0
        total_samples_train = 0

        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device).float().view(-1, 1)

            optimizer.zero_grad()
            outputs = model(inputs)

            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            total_train_loss += loss.item()
            predicted = (outputs > 0.5).float()
            correct_train += (predicted == labels).sum().item()
            total_samples_train += labels.size(0)

        train_accuracy = correct_train / total_samples_train * 100
        train_losses.append(total_train_loss / len(train_loader))
        train_accuracies.append(train_accuracy)

        # Validation loop
        model.eval()
        total_val_loss = 0
        correct_val = 0
        total_samples_val = 0

        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device).float().view(-1, 1)

                outputs = model(inputs)

                loss = criterion(outputs, labels)
                total_val_loss += loss.item()

                predicted = (outputs > 0.5).float()
                correct_val += (predicted == labels).sum().item()
                total_samples_val += labels.size(0)

        val_accuracy = correct_val / total_samples_val * 100
        val_losses.append(total_val_loss / len(val_loader))
        val_accuracies.append(val_accuracy)

        scheduler.step()

        if val_accuracy > best_acc:
            best_acc = val_accuracy
            torch.save(model.state_dict(), 'best_model.pth')

        print(f'Epoch {epoch + 1}/{num_epochs}, Train Loss: {train_losses[-1]:.4f}, Train Acc: {train_accuracy:.2f}%, ' +
              f'Val Loss: {val_losses[-1]:.4f}, Val Acc: {val_accuracy:.2f}%')

    print(f'Training complete. Best Validation Accuracy: {best_acc:.2f}%')

    # Plot training and validation curves
    plot_training_history(train_losses, val_losses, train_accuracies, val_accuracies)

    # Evaluate the model on the validation set
    evaluate_model(model, val_loader, device)

# %% [markdown]
# Evaluate model

# %%
def evaluate_model(model, val_loader, device):
    """
    Evaluate the model on the validation set and generate evaluation metrics.
    """
    model.eval()  # Set the model to evaluation mode
    y_true = []
    y_pred = []

    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device).float().view(-1, 1)
            outputs = model(inputs)
            predicted = (outputs > 0.5).float()  # Convert probabilities to binary predictions
            y_true.extend(labels.cpu().numpy())
            y_pred.extend(predicted.cpu().numpy())

    # Convert lists to numpy arrays
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)

    # Compute evaluation metrics
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)

    # Print evaluation metrics
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1-Score: {f1:.4f}")

    # Plot confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Healthy', 'MDD'])
    disp.plot(cmap=plt.cm.Blues)
    plt.title('Confusion Matrix')
    plt.show()

# %% [markdown]
# Plotting

# %%
def plot_training_history(train_losses, val_losses, train_accuracies, val_accuracies):
    plt.figure(figsize=(12, 5))

    # Plot loss
    plt.subplot(1, 2, 1)
    plt.plot(train_losses, label='Train Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss')
    plt.legend()

    # Plot accuracy
    plt.subplot(1, 2, 2)
    plt.plot(train_accuracies, label='Train Accuracy')
    plt.plot(val_accuracies, label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()

def plot_confusion_matrix(model, val_loader, device):
    model.eval()
    y_true = []
    y_pred = []

    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device).float().view(-1, 1)
            outputs = model(inputs)
            predicted = (outputs > 0.5).float()
            y_true.extend(labels.cpu().numpy())
            y_pred.extend(predicted.cpu().numpy())

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Healthy', 'MDD'])
    disp.plot(cmap=plt.cm.Blues)
    plt.title('Confusion Matrix')
    plt.show()

# %% [markdown]
# Main Function

# %%
if __name__ == "__main__":
    healthy_folder = "D:\Contourlet-CNN\Code\Superlet_image\Copy\Healthy"
    mdd_folder = "D:\Contourlet-CNN\Code\Superlet_image\Copy\MDD"

    train_loader, val_loader = load_and_split_data(healthy_folder, mdd_folder)
    
    model = TransferLearningModel()

  
    train_and_evaluate(model, train_loader, val_loader)
# Out:
# Epoch 1/100, Train Loss: 0.9475, Train Acc: 58.43%, Val Loss: 0.9085, Val Acc: 69.57%
# Epoch 2/100, Train Loss: 0.9202, Train Acc: 61.80%, Val Loss: 0.8765, Val Acc: 69.57%
# Epoch 3/100, Train Loss: 0.9095, Train Acc: 61.80%, Val Loss: 0.8668, Val Acc: 69.57%
# Epoch 4/100, Train Loss: 0.8920, Train Acc: 64.04%, Val Loss: 0.8402, Val Acc: 69.57%
# Epoch 5/100, Train Loss: 0.8681, Train Acc: 76.40%, Val Loss: 0.8219, Val Acc: 82.61%
# Epoch 6/100, Train Loss: 0.8304, Train Acc: 82.02%, Val Loss: 0.7418, Val Acc: 91.30%
# Epoch 7/100, Train Loss: 0.8009, Train Acc: 85.39%, Val Loss: 0.7716, Val Acc: 82.61%
# Epoch 8/100, Train Loss: 0.8257, Train Acc: 78.65%, Val Loss: 0.7372, Val Acc: 86.96%
# Epoch 9/100, Train Loss: 0.7903, Train Acc: 86.52%, Val Loss: 0.7251, Val Acc: 91.30%
# Epoch 10/100, Train Loss: 0.7951, Train Acc: 83.15%, Val Loss: 0.7107, Val Acc: 86.96%
# Epoch 11/100, Train Loss: 0.7772, Train Acc: 85.39%, Val Loss: 0.7925, Val Acc: 82.61%
# Epoch 12/100, Train Loss: 0.7456, Train Acc: 87.64%, Val Loss: 0.7317, Val Acc: 86.96%
# Epoch 13/100, Train Loss: 0.7949, Train Acc: 78.65%, Val Loss: 0.7180, Val Acc: 95.65%
# Epoch 14/100, Train Loss: 0.7695, Train Acc: 84.27%, Val Loss: 0.7007, Val Acc: 91.30%
# Epoch 15/100, Train Loss: 0.7638, Train Acc: 87.64%, Val Loss: 0.7028, Val Acc: 86.96%
# Epoch 16/100, Train Loss: 0.7468, Train Acc: 87.64%, Val Loss: 0.7364, Val Acc: 91.30%
# Epoch 17/100, Train Loss: 0.7737, Train Acc: 84.27%, Val Loss: 0.7155, Val Acc: 86.96%
# Epoch 18/100, Train Loss: 0.7580, Train Acc: 91.01%, Val Loss: 0.7246, Val Acc: 91.30%
# Epoch 19/100, Train Loss: 0.7315, Train Acc: 91.01%, Val Loss: 0.7371, Val Acc: 86.96%
# Epoch 20/100, Train Loss: 0.7477, Train Acc: 91.01%, Val Loss: 0.7095, Val Acc: 91.30%
# Epoch 21/100, Train Loss: 0.7569, Train Acc: 86.52%, Val Loss: 0.7078, Val Acc: 91.30%
# Epoch 22/100, Train Loss: 0.7409, Train Acc: 88.76%, Val Loss: 0.7123, Val Acc: 91.30%
# Epoch 23/100, Train Loss: 0.7423, Train Acc: 87.64%, Val Loss: 0.7459, Val Acc: 86.96%
# Epoch 24/100, Train Loss: 0.7521, Train Acc: 86.52%, Val Loss: 0.6737, Val Acc: 95.65%
# Epoch 25/100, Train Loss: 0.7226, Train Acc: 89.89%, Val Loss: 0.6848, Val Acc: 95.65%
# Epoch 26/100, Train Loss: 0.7480, Train Acc: 89.89%, Val Loss: 0.7492, Val Acc: 86.96%
# Epoch 27/100, Train Loss: 0.7313, Train Acc: 92.13%, Val Loss: 0.7166, Val Acc: 86.96%
# Epoch 28/100, Train Loss: 0.7437, Train Acc: 88.76%, Val Loss: 0.6892, Val Acc: 91.30%
# Epoch 29/100, Train Loss: 0.7318, Train Acc: 91.01%, Val Loss: 0.7351, Val Acc: 86.96%
# Epoch 30/100, Train Loss: 0.7111, Train Acc: 93.26%, Val Loss: 0.6972, Val Acc: 95.65%
# Epoch 31/100, Train Loss: 0.7247, Train Acc: 92.13%, Val Loss: 0.6923, Val Acc: 91.30%
# Epoch 32/100, Train Loss: 0.7398, Train Acc: 85.39%, Val Loss: 0.6864, Val Acc: 91.30%
# Epoch 33/100, Train Loss: 0.7428, Train Acc: 87.64%, Val Loss: 0.6878, Val Acc: 91.30%
# Epoch 34/100, Train Loss: 0.7230, Train Acc: 91.01%, Val Loss: 0.6713, Val Acc: 95.65%
# Epoch 35/100, Train Loss: 0.7172, Train Acc: 89.89%, Val Loss: 0.6789, Val Acc: 95.65%
# Epoch 36/100, Train Loss: 0.7244, Train Acc: 88.76%, Val Loss: 0.7242, Val Acc: 91.30%
# Epoch 37/100, Train Loss: 0.7104, Train Acc: 92.13%, Val Loss: 0.7034, Val Acc: 91.30%
# Epoch 38/100, Train Loss: 0.7160, Train Acc: 91.01%, Val Loss: 0.6906, Val Acc: 91.30%
# Epoch 39/100, Train Loss: 0.7204, Train Acc: 91.01%, Val Loss: 0.6830, Val Acc: 95.65%
# Epoch 40/100, Train Loss: 0.7652, Train Acc: 86.52%, Val Loss: 0.6841, Val Acc: 91.30%
# Epoch 41/100, Train Loss: 0.7206, Train Acc: 91.01%, Val Loss: 0.6703, Val Acc: 95.65%
# Epoch 42/100, Train Loss: 0.7213, Train Acc: 89.89%, Val Loss: 0.6920, Val Acc: 91.30%
# Epoch 43/100, Train Loss: 0.7186, Train Acc: 92.13%, Val Loss: 0.6790, Val Acc: 95.65%
# Epoch 44/100, Train Loss: 0.7115, Train Acc: 93.26%, Val Loss: 0.6799, Val Acc: 91.30%
# Epoch 45/100, Train Loss: 0.7031, Train Acc: 94.38%, Val Loss: 0.6849, Val Acc: 91.30%
# Epoch 46/100, Train Loss: 0.7189, Train Acc: 89.89%, Val Loss: 0.6919, Val Acc: 91.30%
# Epoch 47/100, Train Loss: 0.7127, Train Acc: 93.26%, Val Loss: 0.7501, Val Acc: 91.30%
# Epoch 48/100, Train Loss: 0.6856, Train Acc: 96.63%, Val Loss: 0.6896, Val Acc: 91.30%
# Epoch 49/100, Train Loss: 0.7156, Train Acc: 94.38%, Val Loss: 0.7045, Val Acc: 91.30%
# Epoch 50/100, Train Loss: 0.7258, Train Acc: 89.89%, Val Loss: 0.7142, Val Acc: 91.30%
# Epoch 51/100, Train Loss: 0.7106, Train Acc: 93.26%, Val Loss: 0.6853, Val Acc: 91.30%
# Epoch 52/100, Train Loss: 0.7132, Train Acc: 92.13%, Val Loss: 0.6822, Val Acc: 91.30%
# Epoch 53/100, Train Loss: 0.7269, Train Acc: 89.89%, Val Loss: 0.7035, Val Acc: 91.30%
# Epoch 54/100, Train Loss: 0.7028, Train Acc: 94.38%, Val Loss: 0.6779, Val Acc: 95.65%
# Epoch 55/100, Train Loss: 0.7150, Train Acc: 93.26%, Val Loss: 0.6848, Val Acc: 91.30%
# Epoch 56/100, Train Loss: 0.7196, Train Acc: 92.13%, Val Loss: 0.7297, Val Acc: 91.30%
# Epoch 57/100, Train Loss: 0.6950, Train Acc: 96.63%, Val Loss: 0.6722, Val Acc: 95.65%
# Epoch 58/100, Train Loss: 0.7081, Train Acc: 93.26%, Val Loss: 0.7310, Val Acc: 86.96%
# Epoch 59/100, Train Loss: 0.7099, Train Acc: 94.38%, Val Loss: 0.6760, Val Acc: 95.65%
# Epoch 60/100, Train Loss: 0.7299, Train Acc: 92.13%, Val Loss: 0.6870, Val Acc: 91.30%
# Epoch 61/100, Train Loss: 0.7222, Train Acc: 92.13%, Val Loss: 0.6886, Val Acc: 91.30%
# Epoch 62/100, Train Loss: 0.7066, Train Acc: 93.26%, Val Loss: 0.6938, Val Acc: 91.30%
# Epoch 63/100, Train Loss: 0.7256, Train Acc: 88.76%, Val Loss: 0.6738, Val Acc: 95.65%
# Epoch 64/100, Train Loss: 0.7095, Train Acc: 93.26%, Val Loss: 0.6737, Val Acc: 95.65%
# Epoch 65/100, Train Loss: 0.7421, Train Acc: 88.76%, Val Loss: 0.6873, Val Acc: 91.30%
# Epoch 66/100, Train Loss: 0.7167, Train Acc: 93.26%, Val Loss: 0.6687, Val Acc: 95.65%
# Epoch 67/100, Train Loss: 0.7044, Train Acc: 94.38%, Val Loss: 0.6956, Val Acc: 91.30%
# Epoch 68/100, Train Loss: 0.7006, Train Acc: 94.38%, Val Loss: 0.6795, Val Acc: 95.65%
# Epoch 69/100, Train Loss: 0.7061, Train Acc: 95.51%, Val Loss: 0.6707, Val Acc: 95.65%
# Epoch 70/100, Train Loss: 0.7212, Train Acc: 89.89%, Val Loss: 0.6771, Val Acc: 95.65%
# Epoch 71/100, Train Loss: 0.7173, Train Acc: 91.01%, Val Loss: 0.6717, Val Acc: 95.65%
# Epoch 72/100, Train Loss: 0.7378, Train Acc: 89.89%, Val Loss: 0.6867, Val Acc: 91.30%
# Epoch 73/100, Train Loss: 0.7030, Train Acc: 94.38%, Val Loss: 0.7065, Val Acc: 91.30%
# Epoch 74/100, Train Loss: 0.7265, Train Acc: 91.01%, Val Loss: 0.7069, Val Acc: 91.30%
# Epoch 75/100, Train Loss: 0.6951, Train Acc: 93.26%, Val Loss: 0.6858, Val Acc: 91.30%
# Epoch 76/100, Train Loss: 0.7472, Train Acc: 87.64%, Val Loss: 0.6779, Val Acc: 95.65%
# Epoch 77/100, Train Loss: 0.7033, Train Acc: 94.38%, Val Loss: 0.6701, Val Acc: 95.65%
# Epoch 78/100, Train Loss: 0.7302, Train Acc: 88.76%, Val Loss: 0.6791, Val Acc: 95.65%
# Epoch 79/100, Train Loss: 0.7060, Train Acc: 94.38%, Val Loss: 0.6858, Val Acc: 91.30%
# Epoch 80/100, Train Loss: 0.7054, Train Acc: 94.38%, Val Loss: 0.6854, Val Acc: 95.65%
# Epoch 81/100, Train Loss: 0.7063, Train Acc: 92.13%, Val Loss: 0.6753, Val Acc: 95.65%
# Epoch 82/100, Train Loss: 0.6919, Train Acc: 94.38%, Val Loss: 0.6826, Val Acc: 91.30%
# Epoch 83/100, Train Loss: 0.7074, Train Acc: 92.13%, Val Loss: 0.7372, Val Acc: 86.96%
# Epoch 84/100, Train Loss: 0.7087, Train Acc: 92.13%, Val Loss: 0.6733, Val Acc: 95.65%
# Epoch 85/100, Train Loss: 0.7130, Train Acc: 91.01%, Val Loss: 0.6709, Val Acc: 95.65%
# Epoch 86/100, Train Loss: 0.7166, Train Acc: 92.13%, Val Loss: 0.6872, Val Acc: 91.30%
# Epoch 87/100, Train Loss: 0.7076, Train Acc: 93.26%, Val Loss: 0.6745, Val Acc: 95.65%
# Epoch 88/100, Train Loss: 0.7325, Train Acc: 89.89%, Val Loss: 0.6747, Val Acc: 95.65%
# Epoch 89/100, Train Loss: 0.7084, Train Acc: 92.13%, Val Loss: 0.6867, Val Acc: 95.65%
# Epoch 90/100, Train Loss: 0.6835, Train Acc: 97.75%, Val Loss: 0.6673, Val Acc: 95.65%
# Epoch 91/100, Train Loss: 0.7115, Train Acc: 93.26%, Val Loss: 0.6846, Val Acc: 95.65%
# Epoch 92/100, Train Loss: 0.6909, Train Acc: 95.51%, Val Loss: 0.6688, Val Acc: 95.65%
# Epoch 93/100, Train Loss: 0.7069, Train Acc: 93.26%, Val Loss: 0.7006, Val Acc: 91.30%
# Epoch 94/100, Train Loss: 0.7104, Train Acc: 93.26%, Val Loss: 0.7191, Val Acc: 86.96%
# Epoch 95/100, Train Loss: 0.7153, Train Acc: 91.01%, Val Loss: 0.6740, Val Acc: 95.65%
# Epoch 96/100, Train Loss: 0.6828, Train Acc: 96.63%, Val Loss: 0.6871, Val Acc: 91.30%
# Epoch 97/100, Train Loss: 0.7024, Train Acc: 93.26%, Val Loss: 0.6774, Val Acc: 95.65%
# Epoch 98/100, Train Loss: 0.7122, Train Acc: 93.26%, Val Loss: 0.6894, Val Acc: 91.30%
# Epoch 99/100, Train Loss: 0.7164, Train Acc: 93.26%, Val Loss: 0.6849, Val Acc: 91.30%
# Epoch 100/100, Train Loss: 0.7230, Train Acc: 91.01%, Val Loss: 0.6665, Val Acc: 95.65%
# Training complete. Best Validation Accuracy: 95.65%
# Accuracy: 0.9565
# Precision: 0.9412
# Recall: 1.0000
# F1-Score: 0.9697
