# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import CosineAnnealingLR
from torchvision import transforms, datasets, models
from torch.utils.data import random_split, DataLoader
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, precision_score, recall_score, f1_score
import numpy as np

# Data Augmentation
def get_augmentations():
    return transforms.Compose([
        transforms.RandomResizedCrop(224, scale=(0.8, 1.0)),
        transforms.RandomHorizontalFlip(p=0.5),
        transforms.RandomVerticalFlip(p=0.5),
        transforms.RandomRotation(30),
        transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.3, hue=0.1),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

# ResNet-50 Model
class TransferLearningModel(nn.Module):
    def __init__(self):
        super(TransferLearningModel, self).__init__()
        self.model = models.resnet50(pretrained=True) 
        # Freeze initial layers
        for param in self.model.parameters():
            param.requires_grad = False
        # Fine-tune the last two layers
        for param in self.model.layer4.parameters():
            param.requires_grad = True
        # Replace the final fully connected layer
        self.model.fc = nn.Sequential(
            nn.Linear(self.model.fc.in_features, 128),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(128, 1)
        )

    def forward(self, x):
        return torch.sigmoid(self.model(x))

# %%
def load_and_split_data(healthy_folder, mdd_folder, batch_size=16):
    transform = get_augmentations()
    dataset = datasets.ImageFolder(root=os.path.dirname(healthy_folder), transform=transform)

    # Use 80% for training and 20% for validation
    train_size = int(0.8 * len(dataset))
    val_size = len(dataset) - train_size
    train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=4, pin_memory=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, num_workers=4, pin_memory=True)

    return train_loader, val_loader

def plot_training_history(train_losses, val_losses, train_accuracies, val_accuracies):
    plt.figure(figsize=(12, 5))

   
    plt.subplot(1, 2, 1)
    plt.plot(train_losses, label='Train Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss')
    plt.legend()

   
    plt.subplot(1, 2, 2)
    plt.plot(train_accuracies, label='Train Accuracy')
    plt.plot(val_accuracies, label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()

def plot_confusion_matrix(model, val_loader, device):
    model.eval()
    y_true = []
    y_pred = []

    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device).float().view(-1, 1)
            outputs = model(inputs)
            predicted = (outputs > 0.5).float()
            y_true.extend(labels.cpu().numpy())
            y_pred.extend(predicted.cpu().numpy())

    
    cm = confusion_matrix(y_true, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Healthy', 'MDD'])
    disp.plot(cmap=plt.cm.Blues)
    plt.title('Confusion Matrix')
    plt.show()

def evaluate_model(model, val_loader, device):
    """
    Evaluate the model on the validation set and generate evaluation metrics.
    """
    model.eval()  # Set the model to evaluation mode
    y_true = []
    y_pred = []

    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device).float().view(-1, 1)
            outputs = model(inputs)
            predicted = (outputs > 0.5).float()  # Convert probabilities to binary predictions
            y_true.extend(labels.cpu().numpy())
            y_pred.extend(predicted.cpu().numpy())

    
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)

    
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)

   
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1-Score: {f1:.4f}")

    
    cm = confusion_matrix(y_true, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Healthy', 'MDD'])
    disp.plot(cmap=plt.cm.Blues)
    plt.title('Confusion Matrix')
    plt.show()

def train_and_evaluate(model, train_loader, val_loader, num_epochs=100):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    model = model.to(device)

    
    pos_weight = torch.tensor([2.0]).to(device)  
    criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight)

    
    optimizer = optim.AdamW(model.parameters(), lr=0.0001, weight_decay=1e-4)
    scheduler = CosineAnnealingLR(optimizer, T_max=num_epochs, eta_min=1e-6)

    best_acc = 0.0

   
    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []

    for epoch in range(num_epochs):
       
        model.train()
        total_train_loss = 0
        correct_train = 0
        total_samples_train = 0

        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device).float().view(-1, 1)

            optimizer.zero_grad()
            outputs = model(inputs)

            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            total_train_loss += loss.item()
            predicted = (outputs > 0.5).float()
            correct_train += (predicted == labels).sum().item()
            total_samples_train += labels.size(0)

        train_accuracy = correct_train / total_samples_train * 100
        train_losses.append(total_train_loss / len(train_loader))
        train_accuracies.append(train_accuracy)

        model.eval()
        total_val_loss = 0
        correct_val = 0
        total_samples_val = 0

        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device).float().view(-1, 1)

                outputs = model(inputs)

                loss = criterion(outputs, labels)
                total_val_loss += loss.item()

                predicted = (outputs > 0.5).float()
                correct_val += (predicted == labels).sum().item()
                total_samples_val += labels.size(0)

        val_accuracy = correct_val / total_samples_val * 100
        val_losses.append(total_val_loss / len(val_loader))
        val_accuracies.append(val_accuracy)

        scheduler.step()

        if val_accuracy > best_acc:
            best_acc = val_accuracy
            torch.save(model.state_dict(), 'best_model.pth')

        print(f'Epoch {epoch + 1}/{num_epochs}, Train Loss: {train_losses[-1]:.4f}, Train Acc: {train_accuracy:.2f}%, ' +
              f'Val Loss: {val_losses[-1]:.4f}, Val Acc: {val_accuracy:.2f}%')

    print(f'Training complete. Best Validation Accuracy: {best_acc:.2f}%')


    plot_training_history(train_losses, val_losses, train_accuracies, val_accuracies)

    
    evaluate_model(model, val_loader, device)


if __name__ == "__main__":
    healthy_folder = "D:\Contourlet-CNN\Code\Superlet_image\Copy\Healthy"
    mdd_folder = "D:\Contourlet-CNN\Code\Superlet_image\Copy\MDD"

    # Load data
    train_loader, val_loader = load_and_split_data(healthy_folder, mdd_folder)

    # Initialize the model
    model = TransferLearningModel()

    # Train and evaluate the model
    train_and_evaluate(model, train_loader, val_loader)
# Out:
# c:\Users\sudha\anaconda3\envs\CCNN\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\sudha\anaconda3\envs\CCNN\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1/100, Train Loss: 0.9453, Train Acc: 53.93%, Val Loss: 0.9527, Val Acc: 34.78%
# Epoch 2/100, Train Loss: 0.9035, Train Acc: 60.67%, Val Loss: 0.9517, Val Acc: 34.78%
# Epoch 3/100, Train Loss: 0.8851, Train Acc: 59.55%, Val Loss: 0.9363, Val Acc: 34.78%
# Epoch 4/100, Train Loss: 0.8765, Train Acc: 61.80%, Val Loss: 0.9167, Val Acc: 43.48%
# Epoch 5/100, Train Loss: 0.8321, Train Acc: 68.54%, Val Loss: 0.8782, Val Acc: 60.87%
# Epoch 6/100, Train Loss: 0.8066, Train Acc: 78.65%, Val Loss: 0.8302, Val Acc: 73.91%
# Epoch 7/100, Train Loss: 0.7821, Train Acc: 85.39%, Val Loss: 0.7676, Val Acc: 86.96%
# Epoch 8/100, Train Loss: 0.7621, Train Acc: 88.76%, Val Loss: 0.7895, Val Acc: 78.26%
# Epoch 9/100, Train Loss: 0.7515, Train Acc: 87.64%, Val Loss: 0.7813, Val Acc: 78.26%
# Epoch 10/100, Train Loss: 0.7622, Train Acc: 86.52%, Val Loss: 0.7184, Val Acc: 91.30%
# Epoch 11/100, Train Loss: 0.7301, Train Acc: 89.89%, Val Loss: 0.7505, Val Acc: 86.96%
# Epoch 12/100, Train Loss: 0.7915, Train Acc: 78.65%, Val Loss: 0.7523, Val Acc: 86.96%
# Epoch 13/100, Train Loss: 0.7584, Train Acc: 86.52%, Val Loss: 0.7638, Val Acc: 82.61%
# Epoch 14/100, Train Loss: 0.7400, Train Acc: 87.64%, Val Loss: 0.7122, Val Acc: 91.30%
# Epoch 15/100, Train Loss: 0.7093, Train Acc: 94.38%, Val Loss: 0.7412, Val Acc: 82.61%
# Epoch 16/100, Train Loss: 0.7023, Train Acc: 94.38%, Val Loss: 0.7105, Val Acc: 91.30%
# Epoch 17/100, Train Loss: 0.7192, Train Acc: 93.26%, Val Loss: 0.7073, Val Acc: 91.30%
# Epoch 18/100, Train Loss: 0.7124, Train Acc: 93.26%, Val Loss: 0.7364, Val Acc: 82.61%
# Epoch 19/100, Train Loss: 0.7052, Train Acc: 93.26%, Val Loss: 0.7484, Val Acc: 86.96%
# Epoch 20/100, Train Loss: 0.7075, Train Acc: 93.26%, Val Loss: 0.7063, Val Acc: 91.30%
# Epoch 21/100, Train Loss: 0.6964, Train Acc: 94.38%, Val Loss: 0.7055, Val Acc: 91.30%
# Epoch 22/100, Train Loss: 0.6986, Train Acc: 93.26%, Val Loss: 0.7360, Val Acc: 82.61%
# Epoch 23/100, Train Loss: 0.6967, Train Acc: 94.38%, Val Loss: 0.7206, Val Acc: 91.30%
# Epoch 24/100, Train Loss: 0.7010, Train Acc: 93.26%, Val Loss: 0.7059, Val Acc: 91.30%
# Epoch 25/100, Train Loss: 0.7157, Train Acc: 92.13%, Val Loss: 0.7210, Val Acc: 86.96%
# Epoch 26/100, Train Loss: 0.7093, Train Acc: 89.89%, Val Loss: 0.7042, Val Acc: 91.30%
# Epoch 27/100, Train Loss: 0.6896, Train Acc: 95.51%, Val Loss: 0.7097, Val Acc: 91.30%
# Epoch 28/100, Train Loss: 0.7215, Train Acc: 88.76%, Val Loss: 0.7064, Val Acc: 91.30%
# Epoch 29/100, Train Loss: 0.7052, Train Acc: 94.38%, Val Loss: 0.7040, Val Acc: 91.30%
# Epoch 30/100, Train Loss: 0.6805, Train Acc: 96.63%, Val Loss: 0.6996, Val Acc: 95.65%
# Epoch 31/100, Train Loss: 0.6990, Train Acc: 95.51%, Val Loss: 0.7510, Val Acc: 86.96%
# Epoch 32/100, Train Loss: 0.6870, Train Acc: 96.63%, Val Loss: 0.6854, Val Acc: 95.65%
# Epoch 33/100, Train Loss: 0.6897, Train Acc: 95.51%, Val Loss: 0.7039, Val Acc: 91.30%
# Epoch 34/100, Train Loss: 0.7093, Train Acc: 92.13%, Val Loss: 0.7456, Val Acc: 86.96%
# Epoch 35/100, Train Loss: 0.6894, Train Acc: 95.51%, Val Loss: 0.7044, Val Acc: 91.30%
# Epoch 36/100, Train Loss: 0.6940, Train Acc: 94.38%, Val Loss: 0.7035, Val Acc: 91.30%
# Epoch 37/100, Train Loss: 0.7051, Train Acc: 93.26%, Val Loss: 0.7364, Val Acc: 82.61%
# Epoch 38/100, Train Loss: 0.7016, Train Acc: 93.26%, Val Loss: 0.7160, Val Acc: 91.30%
# Epoch 39/100, Train Loss: 0.7001, Train Acc: 93.26%, Val Loss: 0.7082, Val Acc: 91.30%
# Epoch 40/100, Train Loss: 0.6895, Train Acc: 94.38%, Val Loss: 0.7083, Val Acc: 91.30%
# Epoch 41/100, Train Loss: 0.7341, Train Acc: 87.64%, Val Loss: 0.7175, Val Acc: 86.96%
# Epoch 42/100, Train Loss: 0.6969, Train Acc: 93.26%, Val Loss: 0.6841, Val Acc: 95.65%
# Epoch 43/100, Train Loss: 0.7015, Train Acc: 93.26%, Val Loss: 0.7237, Val Acc: 86.96%
# Epoch 44/100, Train Loss: 0.6899, Train Acc: 95.51%, Val Loss: 0.7322, Val Acc: 86.96%
# Epoch 45/100, Train Loss: 0.6864, Train Acc: 94.38%, Val Loss: 0.7034, Val Acc: 91.30%
# Epoch 46/100, Train Loss: 0.7097, Train Acc: 92.13%, Val Loss: 0.7085, Val Acc: 91.30%
# Epoch 47/100, Train Loss: 0.7095, Train Acc: 92.13%, Val Loss: 0.7055, Val Acc: 91.30%
# Epoch 48/100, Train Loss: 0.7132, Train Acc: 93.26%, Val Loss: 0.7046, Val Acc: 91.30%
# Epoch 49/100, Train Loss: 0.6939, Train Acc: 93.26%, Val Loss: 0.7329, Val Acc: 86.96%
# Epoch 50/100, Train Loss: 0.6982, Train Acc: 95.51%, Val Loss: 0.7564, Val Acc: 86.96%
# Epoch 51/100, Train Loss: 0.6775, Train Acc: 96.63%, Val Loss: 0.7024, Val Acc: 91.30%
# Epoch 52/100, Train Loss: 0.6888, Train Acc: 94.38%, Val Loss: 0.7085, Val Acc: 91.30%
# Epoch 53/100, Train Loss: 0.7041, Train Acc: 92.13%, Val Loss: 0.6943, Val Acc: 91.30%
# Epoch 54/100, Train Loss: 0.6806, Train Acc: 95.51%, Val Loss: 0.6833, Val Acc: 95.65%
# Epoch 55/100, Train Loss: 0.6856, Train Acc: 95.51%, Val Loss: 0.6850, Val Acc: 95.65%
# Epoch 56/100, Train Loss: 0.6800, Train Acc: 95.51%, Val Loss: 0.7022, Val Acc: 91.30%
# Epoch 57/100, Train Loss: 0.6994, Train Acc: 93.26%, Val Loss: 0.7022, Val Acc: 91.30%
# Epoch 58/100, Train Loss: 0.6770, Train Acc: 96.63%, Val Loss: 0.7198, Val Acc: 86.96%
# Epoch 59/100, Train Loss: 0.6929, Train Acc: 94.38%, Val Loss: 0.7007, Val Acc: 91.30%
# Epoch 60/100, Train Loss: 0.6762, Train Acc: 96.63%, Val Loss: 0.7381, Val Acc: 86.96%
# Epoch 61/100, Train Loss: 0.6975, Train Acc: 92.13%, Val Loss: 0.7431, Val Acc: 86.96%
# Epoch 62/100, Train Loss: 0.6975, Train Acc: 93.26%, Val Loss: 0.7070, Val Acc: 91.30%
# Epoch 63/100, Train Loss: 0.6757, Train Acc: 96.63%, Val Loss: 0.7024, Val Acc: 91.30%
# Epoch 64/100, Train Loss: 0.6873, Train Acc: 96.63%, Val Loss: 0.7312, Val Acc: 86.96%
# Epoch 65/100, Train Loss: 0.6980, Train Acc: 93.26%, Val Loss: 0.7025, Val Acc: 91.30%
# Epoch 66/100, Train Loss: 0.6877, Train Acc: 94.38%, Val Loss: 0.7166, Val Acc: 86.96%
# Epoch 67/100, Train Loss: 0.6975, Train Acc: 93.26%, Val Loss: 0.7037, Val Acc: 91.30%
# Epoch 68/100, Train Loss: 0.7009, Train Acc: 93.26%, Val Loss: 0.7226, Val Acc: 86.96%
# Epoch 69/100, Train Loss: 0.7045, Train Acc: 92.13%, Val Loss: 0.7173, Val Acc: 86.96%
# Epoch 70/100, Train Loss: 0.6808, Train Acc: 96.63%, Val Loss: 0.7012, Val Acc: 91.30%
# Epoch 71/100, Train Loss: 0.6821, Train Acc: 96.63%, Val Loss: 0.6843, Val Acc: 95.65%
# Epoch 72/100, Train Loss: 0.6856, Train Acc: 95.51%, Val Loss: 0.7461, Val Acc: 86.96%
# Epoch 73/100, Train Loss: 0.6856, Train Acc: 95.51%, Val Loss: 0.7022, Val Acc: 91.30%
# Epoch 74/100, Train Loss: 0.6997, Train Acc: 92.13%, Val Loss: 0.7054, Val Acc: 91.30%
# Epoch 75/100, Train Loss: 0.6978, Train Acc: 94.38%, Val Loss: 0.7027, Val Acc: 91.30%
# Epoch 76/100, Train Loss: 0.6976, Train Acc: 95.51%, Val Loss: 0.6850, Val Acc: 95.65%
# Epoch 77/100, Train Loss: 0.6917, Train Acc: 94.38%, Val Loss: 0.6916, Val Acc: 91.30%
# Epoch 78/100, Train Loss: 0.6818, Train Acc: 95.51%, Val Loss: 0.7020, Val Acc: 91.30%
# Epoch 79/100, Train Loss: 0.6766, Train Acc: 95.51%, Val Loss: 0.7017, Val Acc: 91.30%
# Epoch 80/100, Train Loss: 0.6894, Train Acc: 94.38%, Val Loss: 0.7060, Val Acc: 91.30%
# Epoch 81/100, Train Loss: 0.7191, Train Acc: 88.76%, Val Loss: 0.7182, Val Acc: 86.96%
# Epoch 82/100, Train Loss: 0.6836, Train Acc: 96.63%, Val Loss: 0.6830, Val Acc: 95.65%
# Epoch 83/100, Train Loss: 0.6980, Train Acc: 93.26%, Val Loss: 0.7022, Val Acc: 91.30%
# Epoch 84/100, Train Loss: 0.6762, Train Acc: 96.63%, Val Loss: 0.7022, Val Acc: 91.30%
# Epoch 85/100, Train Loss: 0.6727, Train Acc: 96.63%, Val Loss: 0.7024, Val Acc: 91.30%
# Epoch 86/100, Train Loss: 0.6789, Train Acc: 96.63%, Val Loss: 0.6841, Val Acc: 95.65%
# Epoch 87/100, Train Loss: 0.6802, Train Acc: 95.51%, Val Loss: 0.7022, Val Acc: 91.30%
# Epoch 88/100, Train Loss: 0.7044, Train Acc: 93.26%, Val Loss: 0.7466, Val Acc: 86.96%
# Epoch 89/100, Train Loss: 0.6903, Train Acc: 95.51%, Val Loss: 0.7021, Val Acc: 91.30%
# Epoch 90/100, Train Loss: 0.6747, Train Acc: 96.63%, Val Loss: 0.7320, Val Acc: 86.96%
# Epoch 91/100, Train Loss: 0.6948, Train Acc: 94.38%, Val Loss: 0.6838, Val Acc: 95.65%
# Epoch 92/100, Train Loss: 0.6897, Train Acc: 94.38%, Val Loss: 0.6927, Val Acc: 95.65%
# Epoch 93/100, Train Loss: 0.6751, Train Acc: 96.63%, Val Loss: 0.7079, Val Acc: 91.30%
# Epoch 94/100, Train Loss: 0.6886, Train Acc: 95.51%, Val Loss: 0.7044, Val Acc: 91.30%
# Epoch 95/100, Train Loss: 0.6998, Train Acc: 92.13%, Val Loss: 0.7054, Val Acc: 91.30%
# Epoch 96/100, Train Loss: 0.6781, Train Acc: 95.51%, Val Loss: 0.6915, Val Acc: 95.65%
# Epoch 97/100, Train Loss: 0.6968, Train Acc: 92.13%, Val Loss: 0.7033, Val Acc: 91.30%
# Epoch 98/100, Train Loss: 0.6819, Train Acc: 95.51%, Val Loss: 0.7022, Val Acc: 91.30%
# Epoch 99/100, Train Loss: 0.6867, Train Acc: 94.38%, Val Loss: 0.6839, Val Acc: 95.65%
# Epoch 100/100, Train Loss: 0.6814, Train Acc: 95.51%, Val Loss: 0.6897, Val Acc: 95.65%
# Training complete. Best Validation Accuracy: 95.65%
# Accuracy: 0.9130
# Precision: 0.8000
# Recall: 1.0000
# F1-Score: 0.8889
